# %%
import csv

# %%
# CSV파일 텍스트를 읽어오는 작업
# csv 파일은 1열로 구성된 구글폼 답안임.
def extract_words_from_csv(file_path):
    words = []

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            for word in row:
                words.append(word)

    return words

# CSV 파일 경로 지정
csv_file_path = '군생활_추억.csv'

# 단어 추출
word_list = extract_words_from_csv(csv_file_path)

word_list[22:77]
# Out:
# ['진급',
#  '배수로작업',
#  '유격',
#  '훈련병 시절 겪은 훈련들',
#  '진급',
#  '전역',
#  '훈련',
#  '다른 용사들과 농담 및 대화 내용',
#  '진급',
#  '진급, gp파견',
#  '정보학교 때 모범상 받은거',
#  '전문하사 임관식',
#  '신교대 수료, 진급',
#  '특급달성',
#  '공수훈련',
#  '전역식 체육대회우승',
#  '체육대회',
#  '별보기',
#  '변사자 수습과 표창수여를 받은 일이 가장 기억에 남습니다.태어나 처음으로 군생활 중 변사자를 직접 눈으로 보게되고 육지로 변사자를 모시게 되었습니다.순간은 겁이 나고 무서웠지만 수습이 끝나고 난 후에 삶에 대해 많은 생각을 하게 되었습니다.',
#  '혹한기, 체육대회, 진급 등',
#  '진급, 전역',
#  '혹한기, 밤에 떠든거',
#  '체육대회, 단결활동',
#  '특급전사, 대민지원, kctc, 진급, 소대단결활동',
#  '진급, 특급전사',
#  '진급',
#  '사격 올 만발, 훈련단에서 일어났던 휴대폰 사건 등',
#  '혹한기훈련',
#  '낚시.',
#  '신교대 중대 1등, 운전병 포상 2회, 특급전사 달성',
#  '모든거',
#  '진급',
#  '전역',
#  '전역',
#  '단결활동, 체육대회',
#  '훈련소 때 행군이나 전투뜀걸음(3km)힘들어하는 소대원의 총을 대신 들고 뛰었음배로 힘들었지만 진심으로 고마워하는 동기의 모습이 되게 인상 깊었습니다',
#  '훈련',
#  '몰래 재밌게 논거',
#  '다같이 회식',
#  '아직 전역을..????',
#  '혹한기훈련',
#  '전역',
#  '모범용사 수상',
#  '전역',
#  '전역 사열',
#  '일병 진급 ㅋㅋ',
#  '군생활 자체로 기억이 남음. 필자에게 필요했던 것들 중 인간관계, 참을성, 지식을 쌓는것을 중요하게 생각해서 이것들을 배울수 있어서 가장 기억에 남음. 비록 사회에서 배울 수 있지만 군대라는 제한된 공간에서 배워 한층 더 성숙해짐.',
#  '동기들과의 추억',
#  '작계 훈련',
#  '추석 체육대회',
#  'GP복무',
#  '참모총장 표창',
#  '블랙호크 탄 것',
#  '표창',
#  '공수훈련']

# %%
def remove_punctuation(word_list):
    new_word_list = []

    for word in word_list:
        new_word = word.replace(",", "").replace("'", "")
        new_word_list.append(new_word)

    return new_word_list

# 단어 리스트에서 쉼표와 작은따옴표 제거
updated_word_list = remove_punctuation(word_list)

updated_word_list[22:77]
# Out:
# ['진급',
#  '배수로작업',
#  '유격',
#  '훈련병 시절 겪은 훈련들',
#  '진급',
#  '전역',
#  '훈련',
#  '다른 용사들과 농담 및 대화 내용',
#  '진급',
#  '진급 gp파견',
#  '정보학교 때 모범상 받은거',
#  '전문하사 임관식',
#  '신교대 수료 진급',
#  '특급달성',
#  '공수훈련',
#  '전역식 체육대회우승',
#  '체육대회',
#  '별보기',
#  '변사자 수습과 표창수여를 받은 일이 가장 기억에 남습니다.태어나 처음으로 군생활 중 변사자를 직접 눈으로 보게되고 육지로 변사자를 모시게 되었습니다.순간은 겁이 나고 무서웠지만 수습이 끝나고 난 후에 삶에 대해 많은 생각을 하게 되었습니다.',
#  '혹한기 체육대회 진급 등',
#  '진급 전역',
#  '혹한기 밤에 떠든거',
#  '체육대회 단결활동',
#  '특급전사 대민지원 kctc 진급 소대단결활동',
#  '진급 특급전사',
#  '진급',
#  '사격 올 만발 훈련단에서 일어났던 휴대폰 사건 등',
#  '혹한기훈련',
#  '낚시.',
#  '신교대 중대 1등 운전병 포상 2회 특급전사 달성',
#  '모든거',
#  '진급',
#  '전역',
#  '전역',
#  '단결활동 체육대회',
#  '훈련소 때 행군이나 전투뜀걸음(3km)힘들어하는 소대원의 총을 대신 들고 뛰었음배로 힘들었지만 진심으로 고마워하는 동기의 모습이 되게 인상 깊었습니다',
#  '훈련',
#  '몰래 재밌게 논거',
#  '다같이 회식',
#  '아직 전역을..????',
#  '혹한기훈련',
#  '전역',
#  '모범용사 수상',
#  '전역',
#  '전역 사열',
#  '일병 진급 ㅋㅋ',
#  '군생활 자체로 기억이 남음. 필자에게 필요했던 것들 중 인간관계 참을성 지식을 쌓는것을 중요하게 생각해서 이것들을 배울수 있어서 가장 기억에 남음. 비록 사회에서 배울 수 있지만 군대라는 제한된 공간에서 배워 한층 더 성숙해짐.',
#  '동기들과의 추억',
#  '작계 훈련',
#  '추석 체육대회',
#  'GP복무',
#  '참모총장 표창',
#  '블랙호크 탄 것',
#  '표창',
#  '공수훈련']

# %%
# 단어로 해체하기 위한 패키지
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\onest\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\onest\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

def extract_nouns(word_list):
    nouns = []

    for word in word_list:
        tokens = word_tokenize(word)
        tagged_words = pos_tag(tokens)

        for tagged_word in tagged_words:
            if tagged_word[1].startswith('NN'):  # 명사 품사 태그 확인
                nouns.append(tagged_word[0])

    return nouns

# 단어 리스트에서 명사 추출
noun_list = extract_nouns(word_list)

noun_list[300:350]
# Out:
# ['참을성',
#  '지식을',
#  '쌓는것을',
#  '중요하게',
#  '생각해서',
#  '이것들을',
#  '배울수',
#  '있어서',
#  '가장',
#  '기억에',
#  '남음',
#  '배울',
#  '수',
#  '있지만',
#  '군대라는',
#  '제한된',
#  '공간에서',
#  '배워',
#  '한층',
#  '더',
#  '성숙해짐',
#  '동기들과의',
#  '추억',
#  '작계',
#  '훈련',
#  '추석',
#  '체육대회',
#  'GP복무',
#  '참모총장',
#  '표창',
#  '탄',
#  '것',
#  '표창',
#  '공수훈련',
#  '일',
#  '비효율적',
#  '일처리',
#  '휴가',
#  '호국훈련',
#  '진급',
#  '전역',
#  '체육대회',
#  '진급',
#  '전입',
#  '및',
#  '전출',
#  '놀았던',
#  '기억',
#  '경고장',
#  '유격']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import os

def generate_wordcloud(word_list):
    # 공백으로 단어들을 연결하여 하나의 문자열로 생성
    text = ' '.join(word_list)

    # 현재 작업 디렉토리의 경로를 가져옴
    current_dir = os.getcwd()

    # 폰트 파일 경로 설정
    font_path = os.path.join(current_dir, 'NanumGothic.ttf') # 한글이 깨져서 현 디렉토리에 나눔고딕 다운로드 후 진행하였음.

    # 워드 클라우드 생성
    wordcloud = WordCloud(width=800, height=400, max_words=50, background_color='white', font_path=font_path).generate(text)

    # 워드 클라우드 이미지 표시
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# 단어 리스트로 워드 클라우드 생성
generate_wordcloud(word_list)
