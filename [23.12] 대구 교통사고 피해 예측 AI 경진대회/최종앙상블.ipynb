# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
sub_mlp = pd.read_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/submission_7.csv')
sub_gru = pd.read_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/submission_15.csv')
sub_ml =  pd.read_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/submission_4.csv')
sub = pd.read_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/data/sample_submission.csv')

# %%
sub_ml
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  4.641217
# 1      ACCIDENT_39610  4.135784
# 2      ACCIDENT_39611  5.481495
# 3      ACCIDENT_39612  5.003578
# 4      ACCIDENT_39613  4.985356
# ...               ...       ...
# 10958  ACCIDENT_50567  4.813531
# 10959  ACCIDENT_50568  4.564523
# 10960  ACCIDENT_50569  4.495626
# 10961  ACCIDENT_50570  4.761037
# 10962  ACCIDENT_50571  4.863421
#
# [10963 rows x 2 columns]

# %%
sub_gru
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  4.041488
# 1      ACCIDENT_39610  3.783230
# 2      ACCIDENT_39611  4.421918
# 3      ACCIDENT_39612  4.386206
# 4      ACCIDENT_39613  4.470482
# ...               ...       ...
# 10958  ACCIDENT_50567  3.759520
# 10959  ACCIDENT_50568  4.200616
# 10960  ACCIDENT_50569  4.153236
# 10961  ACCIDENT_50570  4.259796
# 10962  ACCIDENT_50571  4.148785
#
# [10963 rows x 2 columns]

# %%
sub_mlp
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  3.821263
# 1      ACCIDENT_39610  3.600269
# 2      ACCIDENT_39611  4.634081
# 3      ACCIDENT_39612  4.532421
# 4      ACCIDENT_39613  4.408692
# ...               ...       ...
# 10958  ACCIDENT_50567  4.200776
# 10959  ACCIDENT_50568  4.208104
# 10960  ACCIDENT_50569  4.169465
# 10961  ACCIDENT_50570  4.345581
# 10962  ACCIDENT_50571  4.243227
#
# [10963 rows x 2 columns]

# %% [markdown]
# # 단순 평균

# %%
sub['ECLO'] = (sub_ml['ECLO'] + sub_mlp['ECLO'] + sub_gru['ECLO']) / 3

# %%
sub.to_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/ens_1.csv', index = False)

# %% [markdown]
# # MLP 가중평균

# %%
sub['ECLO'] = (sub_ml['ECLO'] + (sub_mlp['ECLO'] * 2) + sub_gru['ECLO']) / 4
sub.to_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/ens_2.csv', index = False)

# %% [markdown]
# # 딥러닝 앙상블

# %%
sub['ECLO'] = ((sub_mlp['ECLO'] * 2) + sub_gru['ECLO']) / 3
sub.to_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/ens_3.csv', index = False)

# %%
sub['ECLO'] = (sub_ml['ECLO'] + (sub_mlp['ECLO'] * 3) + sub_gru['ECLO']) / 5
sub.to_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/ens_4.csv', index = False)

# %%
sub['ECLO'] = (sub_ml['ECLO'] + (sub_mlp['ECLO'] * 4) + sub_gru['ECLO']) / 6
sub.to_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/ens_5.csv', index = False)

# %%
sub['ECLO'] = (sub_ml['ECLO'] + (sub_mlp['ECLO'] * 5) + sub_gru['ECLO']) / 7
sub.to_csv('/content/drive/MyDrive/Dacon/23_대구교통사고피해예측AI경진대회/submissions/ens_6.csv', index = False)
